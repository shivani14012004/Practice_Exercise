# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani14012004/Practice_Exercise/blob/main/Practice_If_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_fact(n):
  result =1
  for i in range(1,n+1):
    result *=i
  return result
print(check_fact(5))
# Out:
# 120

# %%
#13. Write a Python program to check whether the triangle is equilateral, isosceles or scalene triangle.
side1=int(input("Enter first side1:"))
side2=int(input("Enter first side2:"))
side3=int(input("Enter first side3:"))

if(side1+side2>side3)and(side1+side3>side2)and(side3+side2>side1):
  if side1==side2==side3:
    print("Equilateral Triangle:")
  elif side1==side2 or side1==side3 or side2==side3:
    print("Isoscles Triangle:")

  else:
    print("Scalene Traingle:")
else:
  print("Invalid Traingle:")
# Out:
# Enter first side1:5
# Enter first side2:4
# Enter first side3:8
# Scalene Traingle:

# %%
#14. Write a Python program to calculate profit or loss. Input is selling cost and actual cost.
cp=float(input('Enter the cost price:'))
sp=float(input("Enter the selling price:"))

if sp > cp:
  profit =sp-cp
  print("profit =",profit)

elif cp > sp:
  loss = cp-sp
  print('loss=',loss)

else:
  print('no profit,no loss')
# Out:
# Enter the cost price:1000
# Enter the selling price:1000
# no profit,no loss

# %%
#15.Write a Python program to input marks of five subjects Physics, Chemistry, Biology, Mathematics and Computer. Calculate percentage and grade according to following:
# Percentage >= 90% : Grade A
# Percentage >= 80% : Grade B
# Percentage >= 70% : Grade C
# Percentage >= 60% : Grade D
# Percentage >= 40% : Grade E
# Percentage < 40% : Grade F

physics =float(input("Enter physics marks:"))
Chemistry =float(input("Enter Chemistry marks:"))
biology =float(input("Enter biology marks:"))
mathematics =float(input("Enter mathematics marks:"))
computer=float(input("Enter computer marks:"))

total=physics+Chemistry+biology+mathematics+computer

percentage =(total/500)*100
print("percentage =",percentage)

if percentage >= 90:
  print("Grade A")
elif percentage >=80:
  print('Grade B')
elif percentage >=70:
  print('Grade C')
elif percentage >=60:
  print("Grade D")
elif percentage >=40:
  print('Grade E')
else:
  print("Grade F")
# Out:
# Enter physics marks:80
# Enter Chemistry marks:40
# Enter biology marks:50
# Enter mathematics marks:98
# Enter computer marks:77
# percentage = 69.0
# Grade D

# %%
#16. Write a Python program to input basiPython salary of an employee and calculate its Gross salary according to following:
# Basic Salary <= 10000 : HRA = 20%, DA = 80%
# Basic Salary <= 20000 : HRA = 30%, DA = 90%
# Basic Salary > 20000 : HRA = 35%, DA = 95%

basic_salary=float(input("Enter Basic Salary:"))
if basic_salary <=10000:
  hra=basic_salary *20/100
  da=basic_salary *80/100

elif basic_salary <=20000:
  hra = basic_salary *30/100
  da=basic_salary *90/100

else:
  hra=basic_salary *35/100
  da=basic_salary*95/100

gross_salary =basic_salary+hra+da
print('Hra=',hra)
print('da=',da)
print('gross_salary=',gross_salary)
# Out:
# Enter Basic Salary:12000
# Hra= 3600.0
# da= 10800.0
# gross_salary= 26400.0

# %%
#17. Write a Python program to input electricity unit charges and calculate total electricity bill according to the given condition:
# For first 50 units Rs. 0.50/unit
# For next 100 units Rs. 0.75/unit
# For next 100 units Rs. 1.25/unit
# For unit above 250 Rs. 1.50/unit
# An additional surcharge of 17% is added to the bill
units = float(input("Enter electricity units: "))

if units <= 50:
    bill = units * 0.50

elif units <= 150:
    bill = (50 * 0.50) + ((units - 50) * 0.75)

elif units <= 250:
    bill = (50 * 0.50) + (100 * 0.75) + ((units - 150) * 1.25)

else:
    bill = (50 * 0.50) + (100 * 0.75) + (100 * 1.25) + ((units - 250) * 1.50)

surcharge = bill * 17 / 100

total_bill = bill + surcharge

print("Electricity Bill =", bill)
print("Surcharge =", surcharge)
print("Total Bill =", total_bill)
# Out:
# Enter electricity units: 800
# Electricity Bill = 1050.0
# Surcharge = 178.5
# Total Bill = 1228.5

# %% [markdown]
# #Functions

# %%
#1. Creating and Calling a Function
#Problem Statement: Write a Python program to create a simple function that prints a welcome message.
def welcome():
  print("Welcome to python functions")
welcome()
# Out:
# Welcome to python functions

# %%
#2. Function with Parameters
#Problem Statement: Write a Python program to create a function that accepts a student name and prints a greeting
def greet_student(name):
  print('Hello',name)
student_name='Shivani'
greet_student(student_name)
# Out:
# Hello Shivani

# %%
#3. Function with Return Value
#Problem Statement: Write a Python program to create a function that adds two numbers and returns the result.

def add_number(a,b):
  result=a+b
  return result
answer=add_number(10,20)
print("Sum",answer)
# Out:
# Sum 30

# %%
#4. Passing One Function Output to Another Function
#Problem Statement: Write a Python program where the output of one function is passed as input to another function.
def square(num):
  return num *num
def double(num):
  return num *2
result=double(square(5))
print("Final result:",result)
# Out:
# Final result: 50

# %%
#5. Function with Default Parameter
#Problem Statement: Write a Python program to create a function with a default parameter value.
def course_info(course='python'):
  print("Selected course:",course)

course_info()
course_info("Data science")
# Out:
# Selected course: python
# Selected course: Data science

# %%
#Keyword Arguments
# Problem Statement: Write a Python program to call a function using keyword arguments.

def student_info(name,age,city):
  print("Name",name)
  print("age",age)
  print("city",city)
student_info(city='kolhapur',name='shivani',age=23)
# Out:
# Name shivani
# age 23
# city kolhapur

# %%
#7. Variable Number of Arguments using *args
#Problem Statement: Write a Python program to create a function that can add any number of values.
def add_all(*number):
  total=0
  for n in number:
    total=total+n
  return total
print(add_all(10,20,30))
# Out:
# 60

# %%
#8. Variable Number of Keyword Arguments using **kwargs
#Problem Statement: Write a Python program to accept flexible student details using **kwargs
def profile(**details):
  for key,value in details.items():
    print(key, ":",value)
profile(name="sakshi",course='python',city='kolhapur')
# Out:
# name : sakshi
# course : python
# city : kolhapur

# %%
#9. Local and Global Variables
#Problem Statement: Write a Python program to show the difference between local and global variables.
message='Global message'

def show_message():
  message='Local message'
  print("Inside function:",message)

show_message()
print("Outside function:",message)
# Out:
# Inside function: Local message
# Outside function: Global message

# %%
from re import X
#10. Lambda Function
#Problem Statement: Write a Python program to create a small anonymous function using lambda.
squares=lambda x:x*x
print(squares(3))
# Out:
# 9

# %%
#11. Recursive Function
#Problem Statement: Write a Python program to calculate factorial using recursion.
def factorial(n):
  if n==0:
    return 1
  return n*factorial(n-1)

print('factorial',factorial(5))
# Out:
# factorial 120

# %%
#12. Function with Docstring and Type Hints
#Problem Statement: Write a Python function with a docstring and type hints to calculate simple interest.
def simple_interest(principal:float,rate:float,time:float) ->float:
  #Calculate simple interest using principal ,rate,time.

  return(principal*rate*time)/100
interest=simple_interest(10000,8,2)
print("Simple Interest:",interest)
# Out:
# Simple Interest: 1600.0

# %%
#1. Write a Function to Check Even or Odd
#Problem Statement: Create a function that takes a number and returns whether it is even or odd.
def check_even_odd(num):
  if num%2==0:
    return 'even'
  else:
    return 'odd'
print(check_even_odd(2))
# Out:
# even

# %%
#2. Write a Function to Find the Largest of Three Numbers
#Problem Statement: Create a function that accepts three numbers and returns the largest number.
def largest_of_three(a,b,c):
  if a>=b and a>=c:
    return a
  elif b>=a and b>=c:
    return b
  else:
    return c
print(largest_of_three(10,20,3))
# Out:
# 20

# %%
#3. Write a Function to Calculate Factorial
#Problem Statement: Create a function that returns the factorial of a given number.
def factorial(n):
  if n== 0:
    return 1
  return n*factorial(n-1)

print(factorial(5))
# Out:
# 120

# %%
#4. Write a Function to Check Prime Number
#Problem Statement: Create a function that checks whether a number is prime or not.
def prime(num):
  if num <=1:
    return False

  i = 2
  while i < num:
    if num % i ==0:
      return False
    i=i+1

  return True
print(prime(19))
# Out:
# True

# %%
#5. Write a Function to Reverse a String
#Problem Statement: Create a function that accepts a string and returns the reversed string.
def reverse_string(text):
  result=''
  for ch in text:
    result =ch+result
  return result
print(reverse_string('shivani'))
# Out:
# inavihs

# %%
#6. Write a Function to Count Vowels in a String
#Problem Statement: Create a function that counts vowels in a given string.
def count_vowels(text):
  vowels='aeiouAeiou'
  count = 0
  for ch in text:
    if ch in vowels:
      count +=1
  return count
print(count_vowels('LihaTech Kolhapur'))
# Out:
# 6

# %%
#7. Write a Function to Check Palindrome String
#Problem Statement: Create a function that checks whether a string is palindrome or not.

def palindrome(text):
  cleaned=text.lower()
  return cleaned == cleaned[::-1]

print(palindrome('Madam'))
# Out:
# True

# %%
#8. Write a Function to Generate Fibonacci Series
#Problem Statement: Create a function that returns the Fibonacci series for n terms.

def fibonacci(n):
  series = []
  a,b = 0,1
  count =0

  while count < n:
    series.append(a)
    a,b = b,a + b
    count = count+1
  return series

print(fibonacci(8))
# Out:
# [0, 1, 1, 2, 3, 5, 8, 13]

# %%
def fibonacci(n):
  series=[]
  a,b=0,1
  count=0

  while count < n:
    series.append(a)
    a,b=b,a+b
    count = count +1

  return series
print(fibonacci(8))
# Out:
# [0, 1, 1, 2, 3, 5, 8, 13]
