# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani14012004/Practice_Exercise/blob/main/practiceif_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Write a Python program to find maximum between two numbers.
num1=int(input("Enter a number1:"))
num2=int(input("Enter a number2:"))

if num1>num2:
  print('maximum number is:',num1)
else:
  print('maximum number  is:',num2)
# Out:
# Enter a number1:12
# Enter a number2:67
# maximum number  is: 67

# %%
#2. Write a Python program to find maximum among three numbers.
num1=int(input("Enter a number:"))
num2=int(input("Enter a number:"))
num3=int(input("Enter a  number:"))

if num1>num2:
  print("Maximum number is:",num1)
elif num2>num3:
  print("maximum number is:",num2)
else:
  print("maximum number is:",num3)
# Out:
# Enter a number:45
# Enter a number:98
# Enter a  number:56
# maximum number is: 98

# %%
#3. Write a Python program to check whether a number is negative, positive or zero.
num=int(input("Enter a number:"))
if num >0 :
  print('positive')
elif num<0:
  print('negative')
else:
  print('Zero')
# Out:
# Enter a number:0
# Zero

# %%
#4. Write a Python program to check whether a number is divisible by 5 and 11 or not.
num=int(input("Enter a number:"))
if num % 5==0 and num % 11==0:
  print("number is divisible by 5 and 11")
else:
  print("number is not divisible by 5 and 11")
# Out:
# Enter a number:55
# number is divisible by 5 and 11

# %%
#5. Write a Python program to check whether a number is even or odd.
num=int(input("Enter a number:"))
if num %2==0:
  print('Even')
else:
  print('odd')
# Out:
# Enter a number:2
# Even

# %%
#. 6. Write a Python program to check whether a year is leap year or not.
year=int(input("Enter the number:"))
if (year % 400 == 0) or (year % 4 == 0 and year % 100!=0):
  print("Leap Year")
else:
  print("Not a leap year")
# Out:
# Enter the number:2009
# Not a leap year

# %%
#7. Write a Python program to check whether a character is alphabet or not.
chr=input("Enter a character")
if chr.isalpha():
  print("IT is a alphabet:")
else:
  print("IT is not alphabet:")
# Out:
# Enter a character2323
# IT is not alphabet:

# %%
#8. Write a Python program to input any alphabet and check whether it is vowel or consonant.
ch=input('Enter a string:')
if ch in 'aeiouAeiou':
  print("It is vowel")
else:
  print("It is a consonant")
# Out:
# Enter a string:e
# It is vowel

# %%
#9. Write a Python program to check whether a character is uppercase or lowercase alphabet.
text=input("Enter a string:")
if text in text.upper():
  print("It is upper")
else:
  print("It is lower")
# Out:
# Enter a string:shivani
# It is lower

# %%
#10. Write a Python program to count total number of notes in given amount.
num=int(input("Enter a amount"))
if

# %%
#11. Write a Python program to input angles of a triangle and check whether triangle is valid or not.
angle1=int(input("Enter a triangle:"))
angle2=int(input("Enter a triangle:"))
angle3=int(input("Enter a triangle:"))
if angle1+angle2+angle3==180:
  print("valid")
else:
  print("not valid")
# Out:
# Enter a triangle:23
# Enter a triangle:4
# Enter a triangle:33
# not valid

# %%
#12. Write a Python program to input all sides of a triangle and check whether triangle is valid or not.
side1=int(input("Enter a triangle:"))
side2=int(input("Enter a triangle:"))
side3=int(input("Enter a triangle:"))
if (side1+side2>side3)and(side1+side3>side2)and(side2+side3>side1):
  print("valide")
else:
  print("Not valid")
# Out:
# Enter a triangle:2
# Enter a triangle:5
# Enter a triangle:8
# Not valid

# %%
#13. Write a Python program to check whether the triangle is equilateral, isosceles or scalene triangle.
side1=int(input("Enter a triangle:"))
side2=int(input("Enter a triangle:"))
side3=int(input("Enter a triangle:"))
if side1 == side2 == side3:
  print("Equilateral triangle")
elif side1 == side2 or side2 == side3 or side1 == side3:
  print("Isosceles")

else:
  print("Scalene")
# Out:
# Enter a triangle:3
# Enter a triangle:4
# Enter a triangle:5
# Scalene

# %%
#14. Write a Python program to calculate profit or loss. Input is selling cost and actual cost.
cost_price=float(input("Enter cost price"))
selling_price=float(input("Enter selling price"))
if selling_price > cost_price:
  profit=selling_price - cost_price
  print("profit=",profit)
elif cost_price > selling_price:
  loss=cost_price - selling_price
  print("loss=",loss)
else:
  print("No profit no loss")
# Out:
# Enter cost price500
# Enter selling price500
# No profit no loss

# %%
#15. Write a Python program to input marks of five subjects Physics, Chemistry, Biology, Mathematics and Computer. Calculate percentage and grade according to following: Percentage >= 90% : Grade A Percentage >= 80% : Grade B Percentage >= 70% : Grade C Percentage >= 60% : Grade D Percentage >= 40% : Grade E Percentage < 40% : Grade F
physics=int(input("Enter a physics"))
chemistry=int(input("Enter a chemistry"))
biology=int(input("Enter a Biology"))
mathematics=int(input("Enter a mathematics"))
computer =int(input("Enter a computer"))

total = physics + chemistry + biology + mathematics + computer
percentage=total / 5
print("Total Marks=",total)
print("Percentage =",percentage)

if percentage >=90:
  print("Grade A")
elif percentage >= 80:
  print("Grade B")
elif percentage>=70:
  print("Grade C")
elif percentage >= 70:
  print("Grade D")
elif percentage >=60:
  print("Grade E")
else:
  print("Grade F")
# Out:
# Enter a physics78
# Enter a chemistry87
# Enter a Biology98
# Enter a mathematics67
# Enter a computer56
# Total Marks= 386
# Percentage = 77.2
# Grade C

# %%
#16. Write a Python program to input basiPython salary of an employee and calculate its Gross salary according to following: Basic Salary <= 10000 : HRA = 20%, DA = 80% Basic Salary <= 20000 : HRA = 30%, DA = 90% Basic Salary > 20000 : HRA = 35%, DA = 95%
employee
